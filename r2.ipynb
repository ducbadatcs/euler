# %%
import math
import random
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
n = 100
x = np.linspace(0, 1, n)
y = np.array([random.random() for _ in x])
plt.plot(x, y, "r")
np
# Out:
# <module 'numpy' from 'c:\\Users\\duc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\numpy\\__init__.py'>

# %%
np.mean(y)
# Out:
# np.float64(0.5004768400176409)
